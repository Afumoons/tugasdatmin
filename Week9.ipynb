# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import seaborn as sns; sns.set()
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16,9)
plt.style.use('ggplot')

# %%
dataset=pd.read_csv('D:/Afumoons/OneDrive/Matkul/Data Mining/Eps6 - CLV.csv')

# %%
dataset.head()
# Out:
#    INCOME  SPEND
# 0     233    150
# 1     250    187
# 2     204    172
# 3     236    178
# 4     354    163

# %%
len(dataset)
# Out:
# 303

# %%
#Menentukan jumlah k paling optimal
X= dataset.iloc[:,[0,1]].values

# %%
from sklearn.cluster import KMeans
wcss =[]
for i in range(1,11):
    km=KMeans(n_clusters=i,init='k-means++',max_iter=300,n_init=10,random_state=0)
    km.fit(X)
    wcss.append(km.inertia_)
plt.plot(range(1,11),wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('wcss')
plt.show()

# %%
#Menjalankan k-means k=4
km4=KMeans(n_clusters=4,init='k-means++',max_iter=300,n_init=10,random_state=0)
y_means=km4.fit_predict(X)
#Visualisasi data untuk k=4
plt.scatter(X[y_means==0,0],X[y_means==0,1],s=50,c='purple',label='Cluster1')
plt.scatter(X[y_means==1,0],X[y_means==1,1],s=50,c='blue',label='Cluster2')
plt.scatter(X[y_means==2,0],X[y_means==2,1],s=50,c='green',label='Cluster3')
plt.scatter(X[y_means==3,0],X[y_means==3,1],s=50,c='cyan',label='Cluster4')
plt.scatter(km4.cluster_centers_[:,0],km4.cluster_centers_[:,1],s=200,marker='s',c='red',alpha=0.7,label='Centroids')
plt.title('Segmentasi Pelanggan')
plt.xlabel('Pendapatan tahunan')
plt.ylabel('Pengeluaran tahunan dalam situs xxxx')
plt.legend()
plt.show()

# %%
#Menjalankan k-means k=5
km5=KMeans(n_clusters=5,init='k-means++',max_iter=300,n_init=10,random_state=0)
y_means=km5.fit_predict(X)
#Visualisasi data untuk k=5
plt.scatter(X[y_means==0,0],X[y_means==0,1],s=50,c='purple',label='Cluster1')
plt.scatter(X[y_means==1,0],X[y_means==1,1],s=50,c='blue',label='Cluster2')
plt.scatter(X[y_means==2,0],X[y_means==2,1],s=50,c='green',label='Cluster3')
plt.scatter(X[y_means==3,0],X[y_means==3,1],s=50,c='cyan',label='Cluster4')
plt.scatter(X[y_means==4,0],X[y_means==4,1],s=50,c='yellow',label='Cluster5')
plt.scatter(km5.cluster_centers_[:,0],km5.cluster_centers_[:,1],s=200,marker='s',c='red',alpha=0.7,label='Centroids')
plt.title('Segmentasi Pelanggan')
plt.xlabel('Pendapatan tahunan')
plt.ylabel('Pengeluaran tahunan dalam situs xxxx')
plt.legend()
plt.show()

# %%
#Menjalankan k-means k=6
km6=KMeans(n_clusters=6,init='k-means++',max_iter=300,n_init=10,random_state=0)
y_means=km6.fit_predict(X)
#Visualisasi data untuk k=6
plt.scatter(X[y_means==0,0],X[y_means==0,1],s=50,c='purple',label='Cluster1')
plt.scatter(X[y_means==1,0],X[y_means==1,1],s=50,c='blue',label='Cluster2')
plt.scatter(X[y_means==2,0],X[y_means==2,1],s=50,c='green',label='Cluster3')
plt.scatter(X[y_means==3,0],X[y_means==3,1],s=50,c='cyan',label='Cluster4')
plt.scatter(X[y_means==4,0],X[y_means==4,1],s=50,c='yellow',label='Cluster5')
plt.scatter(X[y_means==5,0],X[y_means==5,1],s=50,c='brown',label='Cluster6')
plt.scatter(km6.cluster_centers_[:,0],km6.cluster_centers_[:,1],s=200,marker='s',c='red',alpha=0.7,label='Centroids')
plt.title('Segmentasi Pelanggan')
plt.xlabel('Pendapatan tahunan')
plt.ylabel('Pengeluaran tahunan dalam situs xxxx')
plt.legend()
plt.show()

# %%
#uji kualitas klaster yang dihasilkan
from sklearn.metrics import silhouette_score
range_n_clusters=[2,3,4,5,6]

for n_clusters in range_n_clusters:
    clusterer= KMeans(n_clusters=n_clusters, init='k-means++',max_iter=300,n_init=10,random_state=0)
    y_means=clusterer.fit_predict(X)
    silhouette_avg=silhouette_score(X,y_means)
    print("jumlah claster =",n_clusters,"nilai average_silhouette =", silhouette_avg)
# Out:
# jumlah claster = 2 nilai average_silhouette = 0.44006694211403197
# jumlah claster = 3 nilai average_silhouette = 0.35962629048722355
# jumlah claster = 4 nilai average_silhouette = 0.3618396084064086
# jumlah claster = 5 nilai average_silhouette = 0.352199348445336
# jumlah claster = 6 nilai average_silhouette = 0.35975391689328834

# %%
#Menjalankan k-means k=2
km2=KMeans(n_clusters=2,init='k-means++',max_iter=300,n_init=10,random_state=0)
y_means=km2.fit_predict(X)
#Visualisasi data untuk k=6
plt.scatter(X[y_means==0,0],X[y_means==0,1],s=50,c='purple',label='Cluster1')
plt.scatter(X[y_means==1,0],X[y_means==1,1],s=50,c='blue',label='Cluster2')
plt.scatter(km2.cluster_centers_[:,0],km2.cluster_centers_[:,1],s=200,marker='s',c='red',alpha=0.7,label='Centroids')
plt.title('Segmentasi Pelanggan')
plt.xlabel('Pendapatan tahunan')
plt.ylabel('Pengeluaran tahunan dalam situs xxxx')
plt.legend()
plt.show()
