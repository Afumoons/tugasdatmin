# %%
import pandas as pd
import tweepy
import json

# %%
consumer_key='xxxxx'
consumer_secret='xxxxx'
access_token='xxxxx-xxxxx'
access_token_secret='xxxxx'

auth=tweepy.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)
api = tweepy.API(auth,wait_on_rate_limit=True,wait_on_rate_limit_notify=True)

# %%
hashtag_yang_dicari='#wfh'
crawl_tweet=api.search(q=hashtag_yang_dicari,count=100,include_entities=False)

# %%
json_data=[r._json for r in crawl_tweet]
df= pd.json_normalize(json_data)

# %%
df.head()
# Out:
#                        created_at                   id               id_str  \
# 0  Sun Dec 06 22:36:30 +0000 2020  1335714763679158274  1335714763679158274
# 1  Sun Dec 06 22:30:49 +0000 2020  1335713330942648320  1335713330942648320
# 2  Sun Dec 06 22:26:47 +0000 2020  1335712317095309313  1335712317095309313
# 3  Sun Dec 06 22:26:00 +0000 2020  1335712121972256770  1335712121972256770
# 4  Sun Dec 06 22:25:04 +0000 2020  1335711884239056899  1335711884239056899
#
#                                                 text  truncated  \
# 0  Stephan Howeg from the Adecco Group shares how...       True
# 1  @miles_k A whole bunch of computer accessories...      False
# 2  Heading to Barangka river bunguio ZC..\n\n#alt...      False
# 3  If your firm's working from home, it's essenti...       True
# 4  I finally have a designated work space! #WFH h...      False
#
#                                               source  in_reply_to_status_id  \
# 0  <a href="https://app.clearviewsocial.com" rel=...                    NaN
# 1  <a href="http://twitter.com/download/android" ...           1.335706e+18
# 2  <a href="http://twitter.com/download/android" ...                    NaN
# 3  <a href="https://buffer.com" rel="nofollow">Bu...                    NaN
# 4  <a href="http://twitter.com/download/iphone" r...                    NaN
#
#   in_reply_to_status_id_str  in_reply_to_user_id in_reply_to_user_id_str  ...  \
# 0                      None                  NaN                    None  ...
# 1       1335706384382521344           17839976.0                17839976  ...
# 2                      None                  NaN                    None  ...
# 3                      None                  NaN                    None  ...
# 4                      None                  NaN                    None  ...
#
#   retweeted_status.quoted_status.coordinates  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   retweeted_status.quoted_status.place  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#   retweeted_status.quoted_status.contributors  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    retweeted_status.quoted_status.is_quote_status  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   retweeted_status.quoted_status.retweet_count  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    retweeted_status.quoted_status.favorite_count  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    retweeted_status.quoted_status.favorited  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    retweeted_status.quoted_status.retweeted  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    retweeted_status.quoted_status.possibly_sensitive  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    retweeted_status.quoted_status.lang
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
# [5 rows x 282 columns]

# %%
#menyimpan menjadi csv
df.to_csv("data_tweet.csv",index=False)
